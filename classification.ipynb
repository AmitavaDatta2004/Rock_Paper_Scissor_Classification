# %% [markdown]
# https://universe.roboflow.com/joseph-nelson/rock-paper-scissors/dataset/1#

# %%
# !pip install --upgrade ultralytics

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="ZkNMlNnyIa2y7w8zGWMS")
project = rf.workspace("joseph-nelson").project("rock-paper-scissors")
version = project.version(1)
dataset = version.download("folder")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Rock-Paper-Scissors-1 in folder:: 100%|██████████| 2927/2927 [00:01<00:00, 2708.75it/s]

# %%
from ultralytics import YOLO

#loading classification model
model = YOLO('yolo11n-cls.pt')

#train the model
results = model.train(data='Rock-Paper-Scissors-1', epochs=10, imgsz=640)
# Out:
# ...
# 100%|██████████| 5.52M/5.52M [00:02<00:00, 2.52MB/s]
# Ultralytics 8.3.28  Python-3.12.6 torch-2.5.1+cpu CPU (12th Gen Intel Core(TM) i5-12500H)
# ...

# %% [markdown]
# # Inference

# %%
from IPython.display import Image

# %%
Image("runs/classify/train3/results.png", width=600)

# %%
model = YOLO('runs/classify/train3/weights/best.pt')

results = model("Rock-Paper-Scissors-1/train/rock/rock01-000_png.rf.560ebe5b8570f6866c33946448ccf7de.jpg") #, save=True, conf=0.5)
Image("Rock-Paper-Scissors-1/train/rock/rock01-000_png.rf.560ebe5b8570f6866c33946448ccf7de.jpg", width=600)
results[0].show()
# Out:
# image 1/1 d:\Projects\Rock_Paper_Scissor_Classification\Rock-Paper-Scissors-1\train\rock\rock01-000_png.rf.560ebe5b8570f6866c33946448ccf7de.jpg: 640x640 rock 1.00, scissors 0.00, paper 0.00, 76.8ms
# Speed: 11.0ms preprocess, 76.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
